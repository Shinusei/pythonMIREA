# %%
class MealyError(Exception):
    pass


class Mealy:
    def __init__(self):
        self.state = 'A'

    def brake(self):
        if self.state == 'A':
            self.state = 'B'
            return 0
        if self.state == 'E':
            self.state = 'E'
            return 7
        raise MealyError('brake')

    def rev(self):
        if self.state == 'B':
            self.state = 'B'
            return 2
        if self.state == 'C':
            self.state = 'D'
            return 3
        if self.state == 'D':
            self.state = 'E'
            return 4
        if self.state == 'E':
            self.state = 'B'
            return 6
        raise MealyError('rev')

    def dash(self):
        if self.state == 'B':
            self.state = 'C'
            return 1
        if self.state == 'E':
            self.state = 'F'
            return 5
        if self.state == 'F':
            self.state = 'D'
            return 8
        raise MealyError('dash')


def test():
    mealy = Mealy()
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.brake() == 0
    assert mealy.state == 'B'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.rev() == 2
    assert mealy.state == 'B'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.dash() == 1
    assert mealy.state == 'C'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.rev() == 3
    assert mealy.state == 'D'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.rev() == 4
    assert mealy.state == 'E'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.brake() == 7
    assert mealy.state == 'E'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.dash() == 5
    assert mealy.state == 'F'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.dash() == 8
    assert mealy.state == 'D'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    mealy.state = 'E'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a
    assert mealy.rev() == 6
    assert mealy.state == 'B'
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a


def a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a:
    a = mealy.state
    try:
        mealy.rev()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.dash()
    except MealyError:
        pass
    mealy.state = a
    try:
        mealy.brake()
    except MealyError:
        pass
    mealy.state = a


def main():
    return Mealy()

# %%
test()
